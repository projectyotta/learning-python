# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
page = requests.get('https://www.youtube.com/feed/trending')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[2]
print(html)
print("done")
# Out:
# <html data-cast-api-enabled="true" lang="en"><head><style name="www-roboto">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v16/W4wDsBUluyw0tK3tykhXEfesZW2xOQ-xsNqO47m55DA.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v16/OLffGBTaF0XFOW1gnuHF0Z0EAVxt0G0biEntp43Qt6E.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v16/RxZJdnzeo3R5zSexge8UUaCWcynf_cDxXwCLxiixG1c.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v16/zN7GBFwfMP4uA6AR0HCoLQ.ttf)format('truetype');}</style><script name="www-roboto">if (docume
# ...

# %%
body = html.find_all("div",{"class":"yt-lockup-thumbnail contains-addto"})
print(body)
# Out:
# [<div class="yt-lockup-thumbnail contains-addto"><a aria-hidden="true" class=" yt-uix-sessionlink spf-link " data-sessionlink="itct=CFgQ3DAYACITCJzfg6Wlv9YCFcGXAwodhBEDXijpHjIIdHJlbmRpbmdaCkZFdHJlbmRpbmc" href="/watch?v=xcaeyJTx4Co"><div class="yt-thumb video-thumb"><span class="yt-thumb-simple">
# <img alt="" data-ytimg="1" height="110" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="https://i.ytimg.com/vi/xcaeyJTx4Co/hqdefault.jpg?sqp=-oaymwEWCMQBEG5IWvKriqkDCQgBFQAAiEIYAQ==&amp;rs=AOn4CLAn9qLqsdQ4J9HDSkqwu0Yq0MVubQ" width="196"/>
# <span aria-hidden="true" class="video-time">17:07</span></span></div></a> <span class="thumb-menu dark-overflow-action-menu video-actions">
# ...

# %%
list1=[]
for i in range(0,len(body)):
    body1=body[i]
    body2 = body1.find_all("a",{"aria-hidden":"true"})
    start_currency='href="'
    end_currency='"><div class="yt-thumb'
    currencystring=str(body2)
    currencystring1=(currencystring[currencystring.find(start_currency)+len(start_currency):currencystring.rfind(end_currency)])
    list1.append("http://www.youtube.com"+currencystring1)

#print(body2)

# %%
print(list1)
# Out:
# ['http://www.youtube.com/watch?v=xcaeyJTx4Co', 'http://www.youtube.com/watch?v=l7yxJDFvTRM', 'http://www.youtube.com/watch?v=OWpSYn40eLc', 'http://www.youtube.com/watch?v=ZcTvrxwP6Is', 'http://www.youtube.com/watch?v=gGILiLTenR8', 'http://www.youtube.com/watch?v=O77l5Z3DEDg', 'http://www.youtube.com/watch?v=YMLLK844QII', 'http://www.youtube.com/watch?v=S_9OSktlm6s', 'http://www.youtube.com/watch?v=dN9hA7J79VI', 'http://www.youtube.com/watch?v=jY9xBAAa5fs', 'http://www.youtube.com/watch?v=8ZRCdfaAIy0', 'http://www.youtube.com/watch?v=D59v74k5flU', 'http://www.youtube.com/watch?v=2Lq5pZrbpHc', 'http://www.youtube.com/watch?v=hOFRbjjjwCE', 'http://www.youtube.com/watch?v=5mgGrx8uaRQ', 'http://www.youtube.com/watch?v=1Q-ZREGfxTI', 'http://www.youtube.com/watch?v=ao21eJgsF1w', 'http://www.youtube.com/watch?v=NJ2asQtT014', 'http://www.youtube.com/watch?v=EmlH7yRKmSY', 'http://www.youtube.com/watch?v=7V1J_MDi9Lg', 'http://www.youtube.com/watch?v=RtEvTmhVeQQ', 'http://www.youtube.com/watch?v
# ...

# %%
xy=pd.DataFrame(list1)
xy
dank= requests.get(xy[0][1])
dank
# Out:
# <Response [200]>

# %%
# loop 
    # use the pytube package to download the videos 
    # get the filenames 
    # download the videos 
    # use ffmpeg4 and opencv to convert videos to set of images 
    # use subprocess package to add additional data ( .rar thing) to the image files 
    # use mouseclick package to figure out how to upload folder to prime photos 
    # wait for 5 hours ( basically to finish the images to upload )  
    # delete images
# Out:
#                                      0
# 0  www.youtube.com/watch?v=xcaeyJTx4Co
# 1  www.youtube.com/watch?v=l7yxJDFvTRM
# 2  www.youtube.com/watch?v=OWpSYn40eLc
# 3  www.youtube.com/watch?v=ZcTvrxwP6Is
# 4  www.youtube.com/watch?v=gGILiLTenR8
