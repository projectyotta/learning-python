# %%
import pandas as pd 
filelist=["wow.xlsx","wave.xlsx"]
print("done")
# Out:
# done

# %%
raw={}

for i in range(0,len(filelist)):
    raw[i]=pd.read_excel(filelist[i])
    print("done")
print("wow done")
# Out:
# done
# done
# wow done

# %%
frames=[raw[i] for i in range(0,len(filelist))]
result=pd.concat(frames)
print("done")
# Out:
# done

# %%
result
# Out:
#     head1  head2 head3 head4      head5  head6 head7 head8  head9
# 0    fewa     gg   gff  sdaf       SDVF   VSDF   HTR   NaN    NaN
# 1      gr     ge     r   NaN        NaN   VSDF   NaN   NaN    NaN
# 2      gr     er   frg   NaN        VSD    NaN   HTR   NaN    NaN
# 3  aeraer  erera   frg   NaN      VSDFA    NaN  HJTR   NaN    NaN
# 4      ga     er   rfa   FSD      VSDFA  SDVFA    JY   NaN    NaN
# 5     gra     ge     a  VSDF        VSD   VSDF   NaN   NaN    NaN
# 6     NaN    NaN   fgr    VZ        VSD   VSDF    JT   NaN    NaN
# 0    fewa     gg   gff  sdaf       jkhg    NaN   NaN   uiy  sdrfh
# 1      gr     ge     r   NaN        NaN    NaN   NaN  khjg    NaN
# 2      gr     er   frg   NaN        uky    NaN   NaN   NaN  hdrts
# 3  aeraer  erera   frg   NaN        kuy    NaN   NaN     g   hdrs
# 4      ga     er   rfa   FSD    kuykuih    NaN   NaN   uiy     hd
# 5     gra     ge     a  VSDF  khjglkjhg    NaN   NaN  VSDF     hd
# ...

# %%
result.to_csv("nignog.csv")
